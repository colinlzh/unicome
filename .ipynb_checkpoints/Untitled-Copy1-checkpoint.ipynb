# %% [markdown]
# ##### n=[0]
# l=[0]
# i =0
# c=0
# left=[]
# right=[]
# compare=[]
# with open("compare",'rb') as ifile:
#     for line in ifile:
#         line=line.decode('utf-8')
#         compare.append(line)
# with open("left",'rb') as ifile:
#     for line in ifile:
#         line=line.decode('utf-8')
#         t=line.split(":")
#         s=line.replace(":"+t[-1],"")
#         left.append(s)
# # print(c)
# with open("right",'rb') as ifile:
#     for line in ifile:
#         line=line.decode('utf-8')
#         t=line.split(":")
#         s=line.replace(":"+t[-1],"")
#         right.append(s)

# %%
n=[0]
l=[0]
i =0
c=0
left=[]
right=[]
compare=[]
dic={}
with open("left",'rb') as ifile:
    for line in ifile:
        line=line.decode('utf-8').strip("\r\n")
        t=line.split(":")
        s=line.replace(":"+t[-1],"")
        dic[s]=int(t[-1])
        left.append(s)
with open("right",'rb') as ifile:
    for line in ifile:
        line=line.decode('utf-8')
        t=line.split(":")
        s=line.replace(":"+t[-1],"")
        right.append(s)
with open("compare",'rb') as ifile:
    for line in ifile:
        line=line.decode('utf-8')
        compare.append(line)

# %%
final=[]
c=0
d=0
flag=False
for i in left:
    testi=i.lower()
    for j in right:
        if testi==j.lower():
            final.append(i+","+j+"\r\n")
            flag=True
            d+=1
            break
    if flag:
        flag=False
    else:
        final.append(i)
    if c==2000:
        break
    c+=1

# %%
re=[]
name=[]
for i in compare:
    name.append(i.split(",")[0])
    re.append(i)
for i in final:
    if i in name:
        continue
    if "," not in i:
        i=i+",????????????\r\n"
    re.append(i)

# %%
name=set(name)
c=0
for i in name:
    c+=dic[i] 
#     print(i)

# %%
len(name)
# Out:
# 208

# %%
c
# Out:
# 692506

# %%
len(re)
# Out:
# 1028

# %%
name=set()
c=0
for i in re:
    name.add(i.split(",")[0])
for i in name:
#     print(i)
    c+=dic[i]

# %%
re
# Out:
# ['A1429,iPhone 5\r\n',
#  'A1586,iPhone 6 (A1586)\r\n',
#  'A1332,iPhone 4\r\n',
#  'A1524,iPhone 6 Plus (A1524)\r\n',
#  'A1528,iPhone 5S\r\n',
#  'A1530,iPhone 5S\r\n',
#  '2013062,MI 3W\r\n',
#  '2013012,MI 2S\r\n',
#  '2013029,Redmi 1S\r\n',
#  'iPhone 4S (A1387),iPhone 4S\r\n',
#  'IPHONE4S(A1387),iPhone 4S\r\n',
#  'AHS3-W,AHS3-W\r\n',
#  '2013023,MI 2013023\r\n',
#  '2014021,Redmi Note\r\n',
#  'GT-I9300,GT-I9300(Galaxy S3)\r\n',
#  'SM-G7106,SM-G7106\r\n',
#  'GT-N7100,GT-N7100(Galaxy Note 2)\r\n',
#  'Nokia 1050,105/1050\r\n',
#  'GT-I9500,GT-I9500(Galaxy S4)\r\n',
#  'A1526,iPhone 5C\r\n',
#  'A1431,iPhone 4S\r\n',
#  'SM-N9002,SM-N9002(Galaxy Note 3)\r\n',
#  'GT-I8552,GT-I8552(Galaxy Win)\r\n',
#  '2014719,MI 4\r\n',
#  '2014811,Redmi X\r\n',
#  '2013022,MI 2013023\r\n',
#  'GT-N7102,GT-N7102\r\n',
#  '2014022,MI 2014022\r\n',
#  '2014022,Redmi  3LTE\r\n',
#  '2014022,Redmi 3\r\n',
#  '2013061,MI 3\r\n',
#  '2013061,MI 3T\r\n',
#  '2013021,MI 2A(CT)\r\n',
#  '2013021,MI 2\r\n',
#  'HUAWEI P7-L09,Ascend P7\r\n',
#  'HUAWEI P7-L09,Ascend P7-L09(Ascend P7)\r\n',
#  'OPPO X909,R815W/X909/X917W/R821W/R820\r\n',
#  'OPPO X909,Find5 X909\r\n',
#  '2014813,Redmi 1s/H2X\r\n',
#  '2014813,H2X\r\n',
#  '2014813,Redmi 1S\r\n',
#  '1280,1280/1282\r\n',
#  'HUAWEI MT7-TL10,MT7-TL10(Ascend Mate7)\r\n',
#  'SM-N9006,SM-N9006(Galaxy Note 3)\r\n',
#  'GT-S7572,GT-S7572\r\n',
#  'H60-L02,H60-L02\r\n',
#  'HTC D516w,D516w\r\n',
#  '2012121,MI 2A\r\n',
#  '2610,2610\r\n',
#  'SM-G3502I,SM-G3502I\r\n',
#  '2014215,MI 4\r\n',
#  '2014616,MI 4\r\n',
#  'H30-U10,H30-U10\r\n',
#  'GT-S7568,GT-S7568\r\n',
#  '2014912,Redmi Note\r\n',
#  '2014501,Redmi 1S\r\n',
#  '2014011,Redmi 1S\r\n',
#  'GT-I9152,GT-I9152\r\n',
#  'SM-G3812,SM-G3812\r\n',
#  'HUAWEI G750-T01,Ascend G750\r\n',
#  'HUAWEI G610-U00,G610-U00\r\n',
#  'GT-I9082i,GT-I9082I\r\n',
#  '2013028,MI 2013028\r\n',
#  '5233,5233\r\n',
#  'ETS3125,ETS3125\r\n',
#  'GT-I9502,GT-I9502\r\n',
#  'Lenovo A3600-d,A3600-d\r\n',
#  'GT-S7562i,GT-S7562I\r\n',
#  '2014022,MI 2014022\r\n',
#  '2014022,Redmi 3\r\n',
#  '2014022,Redmi  3LTE\r\n',
#  'GT-S7562,GT-S7562(Galaxy S DUOS)\r\n',
#  'G620S-UL00,G620S-UL00\r\n',
#  'Che2-UL00,Che2-UL00\r\n',
#  'GT-E1200M,GT-E1200M\r\n',
#  'SM-N900,SM-N900(Galaxy Note 3)\r\n',
#  '101,101/1010\r\n',
#  'SM-A5000,SM-A5000\r\n',
#  'HUAWEI P7-L00,Ascend P7-L00\r\n',
#  'GT-S7562C,GT-S7562C(Galaxy S DUOS)\r\n',
#  'SM-G9006V,SM-G9006V(GALAXY S5)\r\n',
#  '2014502,Redmi Note\r\n',
#  'GT-I9082,GT-I9082(Galaxy Grand DUOS)\r\n',
#  '5230,5230\r\n',
#  'HTC D816w,D816w\r\n',
#  'GT-S7568I,GT-S7568I\r\n',
#  'Lenovo A308t,A308T\r\n',
#  '1208,1208/1209\r\n',
#  'Nokia 1010,1010\r\n',
#  'Che1-CL20,Honor 4X\r\n',
#  'S39h,S39h(Xperia C)\r\n',
#  'GT-I8262D,GT-I8262D\r\n',
#  'Nokia 2060,206/2060\r\n',
#  '1600,1600\r\n',
#  'Nokia 107,107\r\n',
#  'GT-I9152P,GT-I9152P\r\n',
#  'A1533,iPhone 5S\r\n',
#  'Lenovo MA388,MA388\r\n',
#  'A1700,iPhone 6S\r\n',
#  'A1699,iPhone 6S\r\n',
#  'E63,E63\r\n',
#  'M463U,M463U(M1 Note)\r\n',
#  'Lenovo A298t,A298t\r\n',
#  'Lenovo A850,A850\r\n',
#  '1616-2,1616\r\n',
#  'PE-UL00,Honor 6\r\n',
#  '6300,6300\r\n',
#  'Lenovo A300t,A300t\r\n',
#  'SM-N9100,SM-N9100\r\n',
#  'GT-I8268,GT-I8268\r\n',
#  'Lenovo A320t,A320t\r\n',
#  'LA2-S,LA2-S\r\n',
#  'GT-S5830i,GT-S5830I(Galaxy Ace)\r\n',
#  'C1-02,C1-02\r\n',
#  'GT-I9118,GT-I9118\r\n',
#  'H60-L12,Honor 6\r\n',
#  'GALAXYNOTE2GT-N7100,GT-N7100(Galaxy Note 2)\r\n',
#  'SM-N9009,SM-N9009(Galaxy Note 3)\r\n',
#  'SM-A7000,SM-A7000\r\n',
#  'GALAXY NOTE 2 GT-N7100,GT-N7100(Galaxy Note 2)\r\n',
#  'GT-S5830,GT-S5830I(Galaxy Ace)\r\n',
#  '1202-2,1202/1203\r\n',
#  'GT-N7000,GT-N7000\r\n',
#  'M351,M351(MX3)\r\n',
#  'HUAWEI G750-T00,Ascend G750\r\n',
#  'GT-I9100,GT-I9100(Galaxy S2)\r\n',
#  '2014017,Redmi Note\r\n',
#  'HUAWEI ALE-UL00,ALE-UL00\r\n',
#  'PE-TL10,Ascend G730\r\n',
#  'Coolpad 7105,Coolpad 7105\r\n',
#  'Lenovo A318t,A318t\r\n',
#  'SM-G5108Q,SM-G5108Q\r\n',
#  'CHM-UL00,Shine-UL00\r\n',
#  'SCH-N719,SCH-N719\r\n',
#  'TCL i310,i310\r\n',
#  'SM-G3502,SM-G3502\r\n',
#  'Lenovo A388t,A388t\r\n',
#  'HUAWEI Y511-T00,Y511-T00\r\n',
#  'A1529,iPhone 5C\r\n',
#  'OPPO 1107,1107\r\n',
#  'HUAWEI MT2-L05,MT2-L05(Mate 2)\r\n',
#  'GT-I9100G,GT-I9100G\r\n',
#  '2014216,MI 4\r\n',
#  'A1518,iPhone 5S\r\n',
#  '1200,1200\r\n',
#  'GT-I9300I,GT-I9300I\r\n',
#  'SM-N9005,SM-N9005(Galaxy Note 3)\r\n',
#  'GT-S6818,GT-S6818\r\n',
#  'MI-ONE Plus,MI-ONE Plus\r\n',
#  'M461,MX4(M461)\r\n',
#  'vivo Y27,vivo Y27\r\n',
#  'Lenovo A288t,A288t\r\n',
#  'GT-S5230C,GT-S5230C\r\n',
#  'SM-G9200,SM-G9200\r\n',
#  'OPPO R821T,R821T\r\n',
#  'Lenovo A208t,A208t\r\n',
#  '5000,5000\r\n',
#  'vivo X3S W,X3S/X3SW\r\n',
#  'GT-E1200R,GT-E1200R\r\n',
#  'GT-I9082C,GT-I9082C\r\n',
#  '1800,1800\r\n',
#  'PT1608,PT1608\r\n',
#  'GT-S7898,GT-S7898\r\n',
#  'iPhone 5 (A1428),iPhone 5\r\n',
#  'SM-G3818,SM-G3818\r\n',
#  'SCH-I959,SCH-I959\r\n',
#  'M040,MX2\r\n',
#  'G621-TL00,G621-TL00\r\n',
#  'ETS3023,ETS3023\r\n',
#  'SanCup D600,D600\r\n',
#  '2012052,MI 2\r\n',
#  'HUAWEI GRA-UL10,M100-UL10\r\n',
#  'SM-G5308W,SM-G5308W\r\n',
#  'Vogo S350,Vogo S350\r\n',
#  'IPHONE5(A1428),iPhone 5\r\n',
#  'HTC T328w,T328w\r\n',
#  'OPPO R830,R830\r\n',
#  'L36h,C6602/L36h\r\n',
#  'GT-I9507V,GT-I9507V\r\n',
#  'Hol-U10,Hol-U10\r\n',
#  'HTC T528w,One SU(T528w)\r\n',
#  'HUAWEI B199,B199\r\n',
#  'Lenovo A3800-d,A3800-d\r\n',
#  'HUAWEI G750-T20,Honor 3X\r\n',
#  'H30-T00,Honor 3C\r\n',
#  'SM-G3502U,SM-G3502U\r\n',
#  'GT-I9220,GT-I9220\r\n',
#  'vivo X3t,vivo X3t\r\n',
#  'SM-G3586V,SM-G3586V\r\n',
#  'SM-G7508Q,SM-G7508Q\r\n',
#  'LT18i,LT18i\r\n',
#  'Coolpad 8076D,Coolpad 8076\r\n',
#  'SM-G3502C,SM-G3502C\r\n',
#  'M353,M350\r\n',
#  '2015021,X7,xiaominote\r\n',
#  'M201,HG-M200+\r\n',
#  'E261,E261\r\n',
#  'Hol-T00,Hol-T00\r\n',
#  'Nokia 1120,112/1120\r\n',
#  'PT1607,PT1607\r\n',
#  'GT-I9200,GT-I9200(Galaxy Mega)\r\n',
#  'GT-S6352,GT-S6352\r\n',
#  'OPPO R8200,R8100/1100/8200\r\n',
#  'SM-G9250,SM-G9250\r\n',
#  'GT-S5831i,GT-S5831I\r\n',
#  'Lenovo A788t,A788t\r\n',
#  '2013121,2013121\r\n',
#  'PG58130,Sensation XE(G18)(Z715e)(PG58130)\r\n',
#  'SM-N7506V,SM-N7506V\r\n',
#  'SM-G3508I,SM-G3508I\r\n',
#  'RM-1120,RM-1120\r\n',
#  'HUAWEI P6 S-U06,P6S-U06\r\n',
#  'GT-I9168I,GT-I9168I\r\n',
#  'SCL-AL00,SCL-AL00\r\n',
#  'HUAWEI G730-U00,Ascend G730\r\n',
#  'L39h,SONY C6902/L39h\r\n',
#  'HUAWEI G7-UL00,HUAWEI G7-UL00\r\n',
#  'GT-N7108,GT-N7108\r\n',
#  'H30-L02,H30-L02',
#  'AHS3-W,AHS3-W/r/n',
#  'GT-I9300,GT-I9300/r/n',
#  'SM-G7106,SM-G7106/r/n',
#  'GT-N7100,GT-N7100/r/n',
#  'GT-N7102,GT-N7102/r/n',
#  'SM-N9006,SM-N9006/r/n',
#  'GT-S7572,GT-S7572/r/n',
#  'H60-L02,H60-L02/r/n',
#  '2610,2610/r/n',
#  'SM-G3502I,SM-G3502I/r/n',
#  'H30-U10,H30-U10/r/n',
#  'GT-S7568,GT-S7568/r/n',
#  'GT-I9152,GT-I9152/r/n',
#  'SM-G3812,SM-G3812/r/n',
#  '2012061,????????????\r\n',
#  'GT-I9082i,GT-I9082I/r/n',
#  '5233,5233/r/n',
#  'ETS3125,ETS3125/r/n',
#  'GT-I9502,GT-I9502/r/n',
#  'GT-S7562i,GT-S7562I/r/n',
#  'GT-S7562,GT-S7562/r/n',
#  'G620S-UL00,G620S-UL00/r/n',
#  'Che2-UL00,Che2-UL00/r/n',
#  'GT-E1200M,GT-E1200M/r/n',
#  'SM-A5000,SM-A5000/r/n',
#  '5230,5230/r/n',
#  'GT-S7568I,GT-S7568I/r/n',
#  'Che1-CL20,Che1-CL20/r/n',
#  'S39h,S39h/r/n',
#  'GT-I8262D,GT-I8262D/r/n',
#  '1600,1600/r/n',
#  'GT-I9152P,GT-I9152P/r/n',
#  'E63,E63/r/n',
#  '6300,6300/r/n',
#  'SM-N9100,SM-N9100/r/n',
#  'GT-I8268,GT-I8268/r/n',
#  'LA2-S,LA2-S/r/n',
#  'GT-S5830i,GT-S5830I/r/n',
#  'C1-02,C1-02/r/n',
#  'GT-I9118,GT-I9118/r/n',
#  'SM-A7000,SM-A7000/r/n',
#  'GT-S5830,GT-S5830/r/n',
#  'GT-N7000,GT-N7000/r/n',
#  'GT-I9100,GT-I9100/r/n',
#  'Coolpad 7105,Coolpad 7105/r/n',
#  'SM-G5108Q,SM-G5108Q/r/n',
#  'SCH-N719,SCH-N719/r/n',
#  'SM-G3502,SM-G3502/r/n',
#  'GT-I9100G,GT-I9100G/r/n',
#  '1200,1200/r/n',
#  'GT-I9300I,GT-I9300I/r/n',
#  'GT-S6818,GT-S6818/r/n',
#  'MI-ONE Plus,MI-ONE Plus/r/n',
#  'vivo Y27,vivo Y27/r/n',
#  'GT-S5230C,GT-S5230C/r/n',
#  'SM-G9200,SM-G9200/r/n',
#  '5000,5000/r/n',
#  'vivo X3S W,vivo X3S W/r/n',
#  'GT-E1200R,GT-E1200R/r/n',
#  'GT-I9082C,GT-I9082C/r/n',
#  '1800,1800/r/n',
#  'GT-S7898,GT-S7898/r/n',
#  'SM-G3818,SM-G3818/r/n',
#  'SCH-I959,SCH-I959/r/n',
#  'M040,M040/r/n',
#  'G621-TL00,G621-TL00/r/n',
#  'ETS3023,ETS3023/r/n',
#  'SM-G5308W,SM-G5308W/r/n',
#  'Vogo S350,Vogo S350/r/n',
#  'GT-I9507V,GT-I9507V/r/n',
#  'Hol-U10,Hol-U10/r/n',
#  'SM-G3502U,SM-G3502U/r/n',
#  'GT-I9220,GT-I9220/r/n',
#  'vivo X3t,vivo X3t/r/n',
#  'SM-G3586V,SM-G3586V/r/n',
#  'SM-G7508Q,SM-G7508Q/r/n',
#  'LT18i,LT18i/r/n',
#  'SM-G3502C,SM-G3502C/r/n',
#  'E261,E261/r/n',
#  'Hol-T00,Hol-T00/r/n',
#  'GT-S6352,GT-S6352/r/n',
#  'SM-G9250,SM-G9250/r/n',
#  'GT-S5831i,GT-S5831I/r/n',
#  'SM-N7506V,SM-N7506V/r/n',
#  'SM-G3508I,SM-G3508I/r/n',
#  'RM-1120,RM-1120/r/n',
#  'GT-I9168I,GT-I9168I/r/n',
#  'SCL-AL00,SCL-AL00/r/n',
#  'GT-N7108,GT-N7108/r/n',
#  'H30-L02,H30-L02/r/n',
#  'GT-I9508,GT-I9508/r/n',
#  'OPPO R819T,????????????\r\n',
#  'Che1-CL10,Che1-CL10/r/n',
#  'HTC 802w,????????????\r\n',
#  'PT2508,????????????\r\n',
#  'Coolpad 8675-HD,Coolpad 8675-HD/r/n',
#  'SM-G7200,SM-G7200/r/n',
#  'Coolpad 7295C,????????????\r\n',
#  'OPPO R7007,????????????\r\n',
#  'Nokia 520,????????????\r\n',
#  'OPPO R2017,????????????\r\n',
#  'GT-I8558,GT-I8558/r/n',
#  'vivo X5Pro D,vivo X5Pro D/r/n',
#  '7D-501u,????????????\r\n',
#  'E71,E71/r/n',
#  'IPHONE6(A1549),????????????\r\n',
#  'SM-G3608,SM-G3608/r/n',
#  'GT-S3601C,GT-S3601C/r/n',
#  'Lenovo K30-T,????????????\r\n',
#  'ETON S135,????????????\r\n',
#  'HUAWEI MT7-TL00,????????????\r\n',
#  'Lenovo S720,????????????\r\n',
#  'OPPO R831T,????????????\r\n',
#  '2013122,????????????\r\n',
#  'vivo Y23L,vivo Y23L/r/n',
#  '2013063,????????????\r\n',
#  'M98,M98/r/n',
#  'iPhone 6 (A1549),iPhone 6 (A1549)/r/n',
#  'HUAWEI G520-0000,????????????\r\n',
#  'PLK-AL10,PLK-AL10/r/n',
#  'HTC 6160,????????????\r\n',
#  'Coolpad 7296,Coolpad 7296/r/n',
#  '2220s,????????????\r\n',
#  '5130,????????????\r\n',
#  '2014910,????????????\r\n',
#  'XM50h,????????????\r\n',
#  'Lenovo A360t,????????????\r\n',
#  '2014512,????????????\r\n',
#  'HTC 606w,????????????\r\n',
#  'HUAWEI P6-U06,????????????\r\n',
#  'Coolpad 8297W,Coolpad 8297W/r/n',
#  'HUAWEI C8817L,????????????\r\n',
#  'GT-S7898I,GT-S7898I/r/n',
#  'Lenovo MA168,????????????\r\n',
#  'vivo Y13,vivo Y13/r/n',
#  'C8817D,C8817D/r/n',
#  'Lenovo A238t,????????????\r\n',
#  '2014012,????????????\r\n',
#  'C7-00,C7-00/r/n',
#  'GiONEE F103,????????????\r\n',
#  '2220S,????????????\r\n',
#  'HUAWEI G610-T11,????????????\r\n',
#  'Lenovo A60+,????????????\r\n',
#  '2015561,????????????\r\n',
#  'Coolpad 8720L,Coolpad 8720L/r/n',
#  'OPPO R811,????????????\r\n',
#  'M463M,????????????\r\n',
#  'Nokia 1000,????????????\r\n',
#  'Lenovo A880,????????????\r\n',
#  '2014112,????????????\r\n',
#  'GiONEE GN151,????????????\r\n',
#  '3208c,????????????\r\n',
#  '1209,1209/r/n',
#  'Letv X600,????????????\r\n',
#  'E72-1,E72-1/r/n',
#  'SCH-I869,SCH-I869/r/n',
#  'Coolpad 8675-FHD,Coolpad 8675-FHD/r/n',
#  'HUAWEI T8951,????????????\r\n',
#  '100,????????????\r\n',
#  'HUAWEI G6-U00,????????????\r\n',
#  'GT-C6712,????????????\r\n',
#  'CC3-41C11,????????????\r\n',
#  'Che2-TL00M,Che2-TL00M/r/n',
#  'iPhone 3GS (A1303),????????????\r\n',
#  'OPPO R8207,????????????\r\n',
#  'vivo S7i(t),vivo S7i(t)/r/n',
#  '2014018,????????????\r\n',
#  'PD98100,????????????\r\n',
#  'Coolpad 7295,Coolpad 7295/r/n',
#  'OPPO R8007,????????????\r\n',
#  'Lenovo A820,????????????\r\n',
#  'HWCD888(6)GSM1,HWCD888(6)GSM1/r/n',
#  'F669,F669/r/n',
#  'PG88100,PG88100/r/n',
#  '2015712,????????????\r\n',
#  'Lenovo S820,????????????\r\n',
#  'vivo Y11,vivo Y11/r/n',
#  'HUAWEI GRA-UL00,????????????\r\n',
#  '3208C,????????????\r\n',
#  'IPHONE3GS(A1303),????????????\r\n',
#  'vivo Y613,vivo Y613/r/n',
#  'OPPO R831S,????????????\r\n',
#  'HUAWEI RIO-AL00,????????????\r\n',
#  'HUAWEI G700-U00,????????????\r\n',
#  'A1325,????????????\r\n',
#  'ZTE V967S,????????????\r\n',
#  '1116,1116/r/n',
#  'Lenovo A708t,????????????\r\n',
#  'LT26i,????????????\r\n',
#  'F-FOOK F633,????????????\r\n',
#  'ATH-AL00,????????????\r\n',
#  'HUAWEI MT1-U06,????????????\r\n',
#  'Lenovo MA169,????????????\r\n',
#  'OPPO X9070,????????????\r\n',
#  'Lenovo S890,????????????\r\n',
#  'SM-G9008W,SM-G9008W/r/n',
#  'GALAXYS3GT-I9300,????????????\r\n',
#  'Nokia 2020,????????????\r\n',
#  'E66,E66/r/n',
#  'Coolpad 8675-W00,????????????\r\n',
#  '2014812,????????????\r\n',
#  'GT-I9158,GT-I9158/r/n',
#  'HUAWEI Y 220T,????????????\r\n',
#  '7230,????????????\r\n',
#  'PG32130,PG32130/r/n',
#  'RM-969,????????????\r\n',
#  'C5-03,C5-03/r/n',
#  'M571,????????????\r\n',
#  'OPPO R823T,????????????\r\n',
#  'SCH-I829,SCH-I829/r/n',
#  'vivo Y13L,vivo Y13L/r/n',
#  'M462U,????????????\r\n',
#  'vivo X5S L,vivo X5S L/r/n',
#  'RM-978,RM-978/r/n',
#  'HTC D310w,????????????\r\n',
#  'HUAWEI MT7-UL00,????????????\r\n',
#  'SGH-CC03,SGH-CC03/r/n',
#  'Nokia 525,????????????\r\n',
#  'SM-T211,????????????\r\n',
#  'Nokia 106,????????????\r\n',
#  'IPHONE6PLUS(A1522),????????????\r\n',
#  '2014915,????????????\r\n',
#  'Bird-S169,????????????\r\n',
#  'C3-00,C3-00/r/n',
#  'L580,L580/r/n',
#  'GiONEE GN137,????????????\r\n',
#  'ZTE N918St,????????????\r\n',
#  'OPPO R815T,????????????\r\n',
#  'IPHONE6S(A1688),????????????\r\n',
#  'Lenovo K50-t5,????????????\r\n',
#  'SCH-P709,SCH-P709/r/n',
#  '1112,1112/r/n',
#  '2014916,????????????\r\n',
#  'MC001,MC001/r/n',
#  'GiONEE V338,????????????\r\n',
#  'HUAWEI P6-T00,????????????\r\n',
#  'OPPO 3007,????????????\r\n',
#  'N8-00,N8-00/r/n',
#  'Lenovo S850t,????????????\r\n',
#  'SCH-I879,SCH-I879/r/n',
#  'Che2-TL00,Che2-TL00/r/n',
#  'iPhone 6 Plus (A1522),iPhone 6 Plus (A1522)/r/n',
#  'C1-01,C1-01/r/n',
#  'MT15i,MT15i/r/n',
#  'K-Touch T619,K-Touch T619/r/n',
#  'GT-I9308,GT-I9308/r/n',
#  'PT2049,????????????\r\n',
#  'iPad mini (A1455),????????????\r\n',
#  'YQ601,????????????\r\n',
#  'Coolpad 7920,????????????\r\n',
#  'W111,W111/r/n',
#  'vivo Y11i T,vivo Y11i T/r/n',
#  'SM-A3000,SM-A3000/r/n',
#  'SM-G9280,????????????\r\n',
#  'Lenovo P770,????????????\r\n',
#  'IPADMINI(A1455),????????????\r\n',
#  'NX511J,????????????\r\n',
#  'NOAIN 5310,????????????\r\n',
#  'OPPO A31t,????????????\r\n',
#  'SM-A8000,????????????\r\n',
#  'Lenovo S810t,????????????\r\n',
#  'GT-I9158P,GT-I9158P/r/n',
#  'SGH-B108,SGH-B108/r/n',
#  'Lenovo A278t,????????????\r\n',
#  '2012051,????????????\r\n',
#  'HUAWEI G7-TL00,????????????\r\n',
#  'CORBY 2 GT-S3850,????????????\r\n',
#  'SM-E7000,SM-E7000/r/n',
#  'Coolpad 7295A,Coolpad 7295A/r/n',
#  'CHM-TL00H,????????????\r\n',
#  'vivo Y17T,vivo Y17T/r/n',
#  'OPPO R7t,????????????\r\n',
#  'C2-05,C2-05/r/n',
#  'E303,E303/r/n',
#  'SM-G3556D,SM-G3556D/r/n',
#  'Coolpad 8150S,Coolpad 8150S/r/n',
#  'Nokia 920,????????????\r\n',
#  'M460,????????????\r\n',
#  'OPPO R801,????????????\r\n',
#  'SM-N9008S,????????????\r\n',
#  'OPPO R6007,????????????\r\n',
#  'GS100,GS100/r/n',
#  'Coolpad 9190L_C00,????????????\r\n',
#  'Lenovo A789,????????????\r\n',
#  'FN3210,FN3210/r/n',
#  'SM-G5306W,SM-G5306W/r/n',
#  'HUAWEI U9508,????????????\r\n',
#  'GALAXY S3 GT-I9300,????????????\r\n',
#  'ZTE U288,????????????\r\n',
#  'GT-S5360,????????????\r\n',
#  'SanCup D900,????????????\r\n',
#  'HTC M8Sw,????????????\r\n',
#  'GT-S5570,GT-S5570/r/n',
#  'Lenovo S960,????????????\r\n',
#  '1110,1110/r/n',
#  'OPPO R7 Plusm,????????????\r\n',
#  'HUAWEI P6-C00,????????????\r\n',
#  'AOLE 189,AOLE 189/r/n',
#  '2700c,????????????\r\n',
#  'Coolpad 8079,Coolpad 8079/r/n',
#  'vivo Y627,vivo Y627/r/n',
#  'GiONEE GN9006,????????????\r\n',
#  'Coolpad 7620L,Coolpad 7620L/r/n',
#  'MC001S,MC001S/r/n',
#  'GT-S5660,????????????\r\n',
#  'ZTE U817,????????????\r\n',
#  'Coolpad 8070,Coolpad 8070/r/n',
#  '2730c-1,????????????\r\n',
#  'GT-N5100,????????????\r\n',
#  'Lenovo S898t,????????????\r\n',
#  'C520Lw,C520Lw/r/n',
#  '6020,6020/r/n',
#  'Lenovo A630t,????????????\r\n',
#  'Lenovo A658t,????????????\r\n',
#  'C630Lw,????????????\r\n',
#  '2700C,????????????\r\n',
#  '6030,6030/r/n',
#  'GiONEE V182,????????????\r\n',
#  '2690,2690/r/n',
#  'CHE-TL00H,CHE-TL00H/r/n',
#  'Nokia 1320,????????????\r\n',
#  'Lenovo A820t,????????????\r\n',
#  'Lenovo X2-TO,????????????\r\n',
#  'Coolpad 8085,Coolpad 8085/r/n',
#  '1682c,????????????\r\n',
#  'SM-G3508,SM-G3508/r/n',
#  'A520,A520/r/n',
#  '2015052,????????????\r\n',
#  'Coolpad 8705,Coolpad 8705/r/n',
#  'Lenovo A590,????????????\r\n',
#  'SM-N9008,????????????\r\n',
#  '2320c,????????????\r\n',
#  '大显D189,????????????\r\n',
#  'Lenovo A369,????????????\r\n',
#  '2730C-1,????????????\r\n',
#  'GT-I8580,GT-I8580/r/n',
#  'U521,U521/r/n',
#  'ZLT2816,ZLT2816/r/n',
#  'GT-S7278U,GT-S7278U/r/n',
#  'Lenovo A398t+,????????????\r\n',
#  'GT-E1220,GT-E1220/r/n',
#  'Coolpad 8085N,Coolpad 8085N/r/n',
#  'GT-I9260,GT-I9260/r/n',
#  'Coolpad 8297,Coolpad 8297/r/n',
#  'X2-01,X2-01/r/n',
#  'Lenovo A678t,????????????\r\n',
#  'GT-I9505,GT-I9505/r/n',
#  'OPPO X9000,????????????\r\n',
#  'GT-S7278,GT-S7278/r/n',
#  'Lenovo A390t,????????????\r\n',
#  'SanCup H3000,????????????\r\n',
#  'NX403A,????????????\r\n',
#  'OK115,OK115/r/n',
#  'GiONEE V183,????????????\r\n',
#  'MQ4-4411G21,????????????\r\n',
#  'SM-G7109,SM-G7109/r/n',
#  'Lenovo S898t+,????????????\r\n',
#  'OPPO R7sm,????????????\r\n',
#  'GT-E1202,GT-E1202/r/n',
#  '1682C,????????????\r\n',
#  'Lenovo P780,????????????\r\n',
#  'OPPO U705T,????????????\r\n',
#  'SM-T111,SM-T111/r/n',
#  'Coolpad 8297-W01,????????????\r\n',
#  'HTC T327t,????????????\r\n',
#  'vivo X5M,vivo X5M/r/n',
#  'SM-G9009D,SM-G9009D/r/n',
#  'OPPO R813T,????????????\r\n',
#  '2320C,????????????\r\n',
#  'Nokia 1100,????????????\r\n',
#  '7100s,????????????\r\n',
#  'Lenovo A670t,????????????\r\n',
#  'Coolpad 7295+,Coolpad 7295+/r/n',
#  'OPPO U707T,????????????\r\n',
#  'Nokia 925,????????????\r\n',
#  'HUAWEI G620-L75,????????????\r\n',
#  'C2-03,????????????\r\n',
#  'OPPO R827T,????????????\r\n',
#  'F-FOOK F688,????????????\r\n',
#  'GT-S5750E,GT-S5750E/r/n',
#  'Coolpad 8012,Coolpad 8012/r/n',
#  'Coolpad 8675-A,????????????\r\n',
#  'vivo Y22iL,vivo Y22iL/r/n',
#  'Lenovo A628t,????????????\r\n',
#  'PE-CL00,PE-CL00/r/n',
#  'OPPO R7,????????????\r\n',
#  'Coolpad 8297-T01,????????????\r\n',
#  'Nokia 610,????????????\r\n',
#  'Vogo S500,Vogo S500/r/n',
#  'E71-1,E71-1/r/n',
#  'GiONEE GN9000,????????????\r\n',
#  'K-Touch W619,K-Touch W619/r/n',
#  'OPPO 1100,????????????\r\n',
#  'OPPO X907,????????????\r\n',
#  'PLK-UL00,PLK-UL00/r/n',
#  'vivo Y15T,vivo Y15T/r/n',
#  'Lenovo A690,????????????\r\n',
#  'GT-I9250,GT-I9250/r/n',
#  '7100S,????????????\r\n',
#  'IPHONE5S(A1533),????????????\r\n',
#  'W221,W221/r/n',
#  'HUAWEI P7-L07,????????????\r\n',
#  'Lenovo S90-t,????????????\r\n',
#  'SM-G5309W,SM-G5309W/r/n',
#  'AE102,AE102/r/n',
#  'L530G,L530G/r/n',
#  'Lenovo A936,????????????\r\n',
#  'LG-D820,LG-D820/r/n',
#  'BF312,BF312/r/n',
#  'Lenovo S920,????????????\r\n',
#  'SM-G9006W,SM-G9006W/r/n',
#  'GT-E1080C,GT-E1080C/r/n',
#  'Lenovo A380t,????????????\r\n',
#  '金立 E3,????????????\r\n',
#  '大显F189,????????????\r\n',
#  'X1-01,X1-01/r/n',
#  '5800d-1,5800d-1/r/n',
#  'vivo Y18L,vivo Y18L/r/n',
#  'GT-I9128I,GT-I9128I/r/n',
#  'Lenovo A680,????????????\r\n',
#  'iPhone 5S (A1533),????????????\r\n',
#  'XL39h,????????????\r\n',
#  '1650,1650/r/n',
#  '2014911,????????????\r\n',
#  'GT-S3370,GT-S3370/r/n',
#  'DAV-703L,????????????\r\n',
#  'HUAWEI C199s,????????????\r\n',
#  'GT-E1220i,GT-E1220I/r/n',
#  'SM-N9109W,SM-N9109W/r/n',
#  'GD580,GD580/r/n',
#  'Lenovo A218t,????????????\r\n',
#  'ZTE U807,????????????\r\n',
#  'HTC T328t,????????????\r\n',
#  'SM-G3819D,????????????\r\n',
#  'AD3812,AD3812/r/n',
#  'MWQ7-334411A11,????????????\r\n',
#  'vivo S7t,vivo S7t/r/n',
#  'SAGA A738,????????????\r\n',
#  'Coolpad 8076,Coolpad 8076/r/n',
#  'HUAWEI Y635-CL00,????????????\r\n',
#  'vivo X3F,vivo X3F/r/n',
#  'Coolpad 5951,Coolpad 5951/r/n',
#  'vivo Y11iW,vivo Y11iW/r/n',
#  'HUAWEI Y511-U00,????????????\r\n',
#  'Mktel M2,????????????\r\n',
#  'GT-I9158V,GT-I9158V/r/n',
#  '3110c,????????????\r\n',
#  'GT-S7272C,GT-S7272C/r/n',
#  'GT-I9003,????????????\r\n',
#  'SM-G900F,SM-G900F/r/n',
#  'ZTE V956,????????????\r\n',
#  'ZTE V889D,????????????\r\n',
#  'H30-T10,????????????\r\n',
#  '2014821,????????????\r\n',
#  'SM-T311,SM-T311/r/n',
#  'OPPO X9007,????????????\r\n',
#  'N788,N788/r/n',
#  'LT29i,????????????\r\n',
#  'OPPO R829T,????????????\r\n',
#  '5800D-1,5800d-1/r/n',
#  'SGH-C268,SGH-C268/r/n',
#  'BF299,BF299/r/n',
#  'GT-I9128,GT-I9128/r/n',
#  'RM-945,????????????\r\n',
#  'AUX M282+,????????????\r\n',
#  'vivo X5L,vivo X5L/r/n',
#  'iPhone 4S(A1387),iPhone 4S(A1387)/r/n',
#  'BF288,BF288/r/n',
#  'HTC D820u,????????????\r\n',
#  'Lenovo A520,????????????\r\n',
#  'HM-M209,HM-M209/r/n',
#  '1661-2,????????????\r\n',
#  'GT-S6102E,GT-S6102E/r/n',
#  'GiONEE E6,????????????\r\n',
#  'OPPO R8107,????????????\r\n',
#  'E81t,E81t/r/n',
#  '5235,5235/r/n',
#  'SM-G9008V,SM-G9008V/r/n',
#  'Coolpad 7269,Coolpad 7269/r/n',
#  'Lenovo A760,????????????\r\n',
#  'SAGA A820,????????????\r\n',
#  'HUAWEI C199,????????????\r\n',
#  'Lenovo A368t,????????????\r\n',
#  'GT-I9000,????????????\r\n',
#  'iPad mini (A1490),????????????\r\n',
#  '3110C,????????????\r\n',
#  'Lenovo A366t,????????????\r\n',
#  'Lenovo A656,????????????\r\n',
#  'vivo Y623,????????????\r\n',
#  'GT-C3520,GT-C3520/r/n',
#  'HUAWEI G7-UL20,????????????\r\n',
#  'GS101,GS101/r/n',
#  'HUAWEI A199,????????????\r\n',
#  'SM-G7108V,SM-G7108V/r/n',
#  'GT-E1088C,GT-E1088C/r/n',
#  'GT-E1220I,GT-E1220I/r/n',
#  'S3600C,????????????\r\n',
#  'S55u,????????????\r\n',
#  'Lenovo A65,????????????\r\n',
#  'H60-L01,????????????\r\n',
#  'SM-G3588V,SM-G3588V/r/n',
#  'GT-I9168,GT-I9168/r/n',
#  'ETON S127,????????????\r\n',
#  'GT-E1228,GT-E1228/r/n',
#  'AE609,AE609/r/n',
#  '1680c,????????????\r\n',
#  'DC4-41H11,????????????\r\n',
#  'GT-S3850,????????????\r\n',
#  'HUAWEI G5000,????????????\r\n',
#  'vivo X5Max+,vivo X5Max+/r/n',
#  'NX507J,????????????\r\n',
#  '5250,5250/r/n',
#  'SanCup L888,????????????\r\n',
#  'Bird-D719,????????????\r\n',
#  'PG76100,????????????\r\n',
#  'chuangya CY2768,chuangya CY2768/r/n',
#  'Lenovo S850,????????????\r\n',
#  'K68w,K68w/r/n',
#  'LT26ii,????????????\r\n',
#  'HUAWEIG5000,????????????\r\n',
#  'Lenovo A5800-D,????????????\r\n',
#  'Lenovo A806,????????????\r\n',
#  'RM-980,????????????\r\n',
#  'Lenovo A396,????????????\r\n',
#  'iPhone 4 (A1332),????????????\r\n',
#  'ZTE V9180,????????????\r\n',
#  'Lenovo A66,????????????\r\n',
#  'SM-N9008V,????????????\r\n',
#  'NX503A,????????????\r\n',
#  '1681c,????????????\r\n',
#  'vivo X520L,vivo X520L/r/n',
#  'Y900,Y900/r/n',
#  'X3-00,X3-00/r/n',
#  'EA138,EA138/r/n',
#  'HTC D516t,????????????\r\n',
#  'E91w,E91w/r/n',
#  'SM-G3568V,SM-G3568V/r/n',
#  '金立 V100,????????????\r\n',
#  'C2-01,C2-01/r/n',
#  'ZTE V818,????????????\r\n',
#  'HUAWEI U8825D,????????????\r\n',
#  'Coolpad 8085Q,????????????\r\n',
#  'Coolpad 8670,Coolpad 8670/r/n',
#  'GT-S6812i,????????????\r\n',
#  'SCH-I939D,SCH-I939D/r/n',
#  'GT-I8150,????????????\r\n',
#  'OPPO N5117,????????????\r\n',
#  'M580,M580/r/n',
#  'E1100C,E1100C/r/n',
#  'HTC 802t,????????????\r\n',
#  'Coolpad 8198W,Coolpad 8198W/r/n',
#  'PE-TL20,????????????\r\n',
#  'Nokia 3050,????????????\r\n',
#  '2626,2626/r/n',
#  'US88T,????????????\r\n',
#  'HTC T329t,????????????\r\n',
#  'MI-ONEPLUS,????????????\r\n',
#  'OPPO A31,????????????\r\n',
#  'N97-4,????????????\r\n',
#  'GT-S6358,GT-S6358/r/n',
#  'HUAWEI CRR-UL00,????????????\r\n',
#  'IPHONE5S(A1453),????????????\r\n',
#  'BOWAY N18,????????????\r\n',
#  '1680C,????????????\r\n',
#  'SM-G3606,SM-G3606/r/n',
#  'GT-I9128E,GT-I9128E/r/n',
#  'IPHONE4(A1332),????????????\r\n',
#  'RM-1035,RM-1035/r/n',
#  'SCH-I779,SCH-I779/r/n',
#  'iPhone 5S (A1453),????????????\r\n',
#  '1681C,????????????\r\n',
#  'OZZO-126,????????????\r\n',
#  'HUAWEI HN3-U01,????????????\r\n',
#  '5300,????????????\r\n',
#  '2015617,????????????\r\n',
#  'BBKI508,????????????\r\n',
#  'Lenovo A890e,????????????\r\n',
#  'OPPO N5110,????????????\r\n',
#  'Coolpad Y75,Coolpad Y75/r/n',
#  'HUAWEI G630-U00,????????????\r\n',
#  'GiONEE V185,????????????\r\n',
#  'ONE A0001,ONE A0001/r/n',
#  'BBK i508,????????????\r\n',
#  'GiONEE GN9005,????????????\r\n',
#  'GT-P3100,GT-P3100/r/n',
#  'RM-1090,RM-1090/r/n',
#  'Coolpad 5952,????????????\r\n',
#  'Lenovo S60-t,????????????\r\n',
#  'K-Touch T619+,K-Touch T619+/r/n',
#  'Nokia 1520,????????????\r\n',
#  'LT22i,????????????\r\n',
#  'A207,A207/r/n',
#  'BC3-41B11,????????????\r\n',
#  'OPPO A113K,????????????\r\n',
#  'SCH-P709E,SCH-P709E/r/n',
#  'WX180,WX180/r/n',
#  'A8588,A8588/r/n',
#  'A115K,A115K/r/n',
#  'vivo Y29L,vivo Y29L/r/n',
#  'L50u,????????????\r\n',
#  'Lenovo A269i,????????????\r\n',
#  'M465A,M465A/r/n',
#  'SH9120C,SH9120C/r/n',
#  'KF350,KF350/r/n',
#  'LEWAY L006,????????????\r\n',
#  'OPPO A201,????????????\r\n',
#  'CORBY2GT-S3850,????????????\r\n',
#  'vivo Y20T,vivo Y20T/r/n',
#  'GT-I9105P,GT-I9105P/r/n',
#  'Coolpad 8060,Coolpad 8060/r/n',
#  'RM-1011,RM-1011/r/n',
#  'Lenovo A2800-d,????????????\r\n',
#  'A201,A201/r/n',
#  'OPPO R815W,????????????\r\n',
#  'GT-S8500,GT-S8500/r/n',
#  'HUAWEI G610-T00,????????????\r\n',
#  'vivo X3L,vivo X3L/r/n',
#  'OPPOA113K,????????????\r\n',
#  'HUAWEI G510-0010,????????????\r\n',
#  'E82L,E82L/r/n',
#  'HUAWEI G610-C00,????????????\r\n',
#  'Coolpad Y76,Coolpad Y76/r/n',
#  'lenovo A376,????????????\r\n',
#  'SM-G9009W,SM-G9009W/r/n',
#  'H20000,????????????\r\n',
#  'XT390,XT390/r/n',
#  'C1-00,C1-00/r/n',
#  'SM701,SM701/r/n',
#  'Lenovo A798t,????????????\r\n',
#  'RM-944,????????????\r\n',
#  'A8688,A8688/r/n',
#  'C6-00,C6-00/r/n',
#  'GT-E1190,GT-E1190/r/n',
#  'AOLE 568,AOLE 568/r/n',
#  'C2-07,????????????\r\n',
#  'Coolpad 5950,Coolpad 5950/r/n',
#  'SM-G900H,SM-G900H/r/n',
#  'AOLE568,????????????\r\n',
#  'OPPOA201,????????????\r\n',
#  'NOAIN 6700C,????????????\r\n',
#  'HUAWEI G660-L075,????????????\r\n',
#  'HUAWEI ALE-TL00,????????????\r\n',
#  'Coolpad 8702D,Coolpad 8702D/r/n',
#  'IPADMINI(A1490),????????????\r\n',
#  'MCQ6-14411A11,????????????\r\n',
#  'Coolpad 8730L,Coolpad 8730L/r/n',
#  'Coolpad 8297_T01,????????????\r\n',
#  'lenovo A505e,????????????\r\n',
#  'TCL S188,????????????\r\n',
#  'HUAWEI G520-5000,????????????\r\n',
#  'ETS315M,ETS315M/r/n',
#  'Nokia 7610,????????????\r\n',
#  'vivo X510w,vivo X510w/r/n',
#  'Z1108,Z1108/r/n',
#  '金立 GN700W,????????????\r\n',
#  'MI-ONE C1,MI-ONE C1/r/n',
#  'Desire,????????????\r\n',
#  'iPhone 3G A1241,????????????\r\n',
#  'A1589,????????????\r\n',
#  'WP A3,WP A3/r/n',
#  'SGH-C158,SGH-C158/r/n',
#  'HUAWEI G620-L72,????????????\r\n',
#  'Nokia C1-02i,????????????\r\n',
#  'ZTE U790,????????????\r\n',
#  'vivo S7,vivo S7/r/n',
#  'Coolpad 8297D,????????????\r\n',
#  'LG-D821,LG-D821/r/n',
#  'Letv X800,????????????\r\n',
#  'vivo X510t,vivo X510t/r/n',
#  '2630,2630/r/n',
#  'M462,????????????\r\n',
#  'GT-S5838,GT-S5838/r/n',
#  'TCLS188,????????????\r\n',
#  'N198,N198/r/n',
#  'SM-G8508S,SM-G8508S/r/n',
#  'Lenovo P700i,????????????\r\n',
#  'MK260,MK260/r/n',
#  'NOKIA7610,????????????\r\n',
#  'F-FOOK F611,????????????\r\n',
#  'ZTE-T U880,ZTE-T U880/r/n',
#  'GT-E1150C,GT-E1150C/r/n',
#  'OPPO R7005,????????????\r\n',
#  'HUAWEI Y518-T00,????????????\r\n',
#  'Nokia 909,????????????\r\n',
#  'Coolpad 7019A,Coolpad 7019A/r/n',
#  'CHM-TL00,????????????\r\n',
#  'GiONEE X805,????????????\r\n',
#  'HTC A510e,????????????\r\n',
#  'H30-C00,????????????\r\n',
#  'Coolpad 8190,Coolpad 8190/r/n',
#  'OPPO 1105,????????????\r\n',
#  'X6-00,X6-00/r/n',
#  'A1532,????????????\r\n',
#  'HUAWEI Y635-TL00,????????????\r\n',
#  'M0C4D,????????????\r\n',
#  'SM-N9200,????????????\r\n',
#  'OK102,OK102/r/n',
#  'PB99200,????????????\r\n',
#  'GT-S3650C,GT-S3650C/r/n',
#  '6070,6070/r/n',
#  'WP P3000,WP P3000/r/n',
#  'Lenovo S650,????????????\r\n',
#  'DESIRE,????????????\r\n',
#  'Lenovo A850+,????????????\r\n',
#  'X2-00,X2-00/r/n',
#  'LG-D802,LG-D802/r/n',
#  'OPPO N1T,????????????\r\n',
#  'WP A1,WP A1/r/n',
#  'SM-G5108,SM-G5108/r/n',
#  'GALAXY ACE,????????????\r\n',
#  'HUAWEI G730-T00,????????????\r\n',
#  'HUAWEI G525-U00,????????????\r\n',
#  'SCL-TL00H,????????????\r\n',
#  'SGH-C188,SGH-C188/r/n',
#  'E63-1,E63-1/r/n',
#  'SGH-C288,SGH-C288/r/n',
#  'DX886,????????????\r\n',
#  'IPHONE3GA1241,????????????\r\n',
#  'vivo S11t,vivo S11t/r/n',
#  'Nokia 208,????????????\r\n',
#  'Nokia 510,????????????\r\n',
#  'HTC T328d,????????????\r\n',
#  'chuangya CY1702,chuangya CY1702/r/n',
#  'E1750,E1750/r/n',
#  'Coolpad 7236,????????????\r\n',
#  'HUAWEI G606-T00,????????????\r\n',
#  'HUAWEI Y310-5000,????????????\r\n',
#  'BF5600S,BF5600S/r/n',
#  'KEBAO KB1288,KEBAO KB1288/r/n',
#  'Philips X2560,Philips X2560/r/n',
#  'Coolpad 7270,????????????\r\n',
#  'OPPO A100,????????????\r\n',
#  'PI39200,????????????\r\n',
#  'OPPO U701,????????????\r\n',
#  'GB101,????????????\r\n',
#  'UT919,UT919/r/n',
#  'TW99,????????????\r\n',
#  'Lenovo A398t,????????????\r\n',
#  'BF158,????????????\r\n',
#  'C2-06,C2-06/r/n',
#  'Coolpad 8089,Coolpad 8089/r/n',
#  'GT-I8258,GT-I8258/r/n',
#  'CC3-41E11,????????????\r\n',
#  'OPPO X909T,????????????\r\n',
#  'Lenovo S658t,????????????\r\n',
#  'Lenovo A800,????????????\r\n',
#  '2014218,????????????\r\n',
#  'iPad (A1460),????????????\r\n',
#  'NOKIA1600,????????????\r\n',
#  'Coolpad 8190Q,Coolpad 8190Q/r/n',
#  'E1070C,E1070C/r/n',
#  'GT-S6812C,????????????\r\n',
#  'ZTE N958St,????????????\r\n',
#  'GT-S5670,GT-S5670/r/n',
#  'vivo X1St,vivo X1St/r/n',
#  'VEVA A309,VEVA A309/r/n',
#  'GiONEE M5,????????????\r\n',
#  'DX800,????????????\r\n',
#  'SGH-CC01,SGH-CC01/r/n',
#  'Lenovo A830,????????????\r\n',
#  'Lenovo S880i,????????????\r\n',
#  'IPAD(A1460),????????????\r\n',
#  'SM-J7008,????????????\r\n',
#  'ZTE Q503U,????????????\r\n',
#  '2015051,????????????\r\n',
#  'GT-S3778,GT-S3778/r/n',
#  'SM-G7108,SM-G7108/r/n',
#  'HTC S710e,????????????\r\n',
#  'VEVAA309,????????????\r\n',
#  'ZTE U795,????????????\r\n',
#  'GT-I9268,GT-I9268/r/n',
#  '5800,????????????\r\n',
#  'SCH-I679,SCH-I679/r/n',
#  'BF619,BF619/r/n',
#  'PG86300,????????????\r\n',
#  'Lenovo A3000-H,????????????\r\n',
#  'K88L,K88L/r/n',
#  'SHV-E250S,SHV-E250S/r/n',
#  'Letv X500,????????????\r\n',
#  'Lenovo A378t,????????????\r\n',
#  'SM-A7009,SM-A7009/r/n',
#  ...]

# %%
file_object = open('compare1', 'wb')
for i in re:
    file_object.write(i.encode("utf-8"))
file_object.close( )
